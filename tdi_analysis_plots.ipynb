# %% [markdown]
# Analysis and plotting of results stored in pandas dataframes

# %%
import numpy as np
import pandas as pd
import scipy as sp


#import matplotlib
#matplotlib.use('MacOSX')
#%matplotlib 
#import matplotlib.pyplot as plt

Ha_to_eV = 2.721138385465e+01
#plt.close('all')

# %%
# Saved Table locations:

#!ls /Users/swahl/dat/pleiades/tables

#tab_num = '20140110-142950'
tab_num = '20140327-154609'

cmc_file = '/Users/swahl/dat/pleiades/tables/cmc_all_'+tab_num+'.df'
dft_file = '/Users/swahl/dat/pleiades/tables/dft_all_'+tab_num+'.df'
eos_file = '/Users/swahl/dat/pleiades/tables/dft_eos_all_'+tab_num+'.df'
tdi_file = '/Users/swahl/dat/pleiades/tables/tdi_all_'+tab_num+'.df'

# load files
import pandas as pd
cmc = pd.read_pickle(cmc_file)
dft = pd.read_pickle(dft_file)
eos = pd.read_pickle(eos_file)
tdi = pd.read_pickle(tdi_file)

#tdi
tdi.columns
# Out:
# Index([u'F_cl_dft', u'F_dft', u'G_dft', u'P_target', u'P_targetV', u'U_dft', u'cmc_id', u'dV_var', u'dV_var_eV', u'dVcell', u'dft_id', u'dft_to_cl_ids', u'functional', u'kpoints', u'lambdas', u'num_lambda', u'result_file', u'system', u'temp', u'volume'], dtype='object')

# %%
# Calculate -TS and S for each tdi entry
F = tdi.F_dft.tolist()
U = tdi.U_dft.tolist()
T = tdi.temp.tolist()
minusTS = [ ( f[0]-u[0],np.abs(f[1])+np.abs(u[1]) ) for f,u in zip(F,U) ]
minusTS
S_dft =  [(- x[0] / t,- x[1] / t) for x,t in zip(minusTS,T)]
S_dft
tdi['minusTS'] = minusTS
tdi['S_dft'] = S_dft

tdi

#tdi['S_dft']
# Out:
#                               F_cl_dft                        F_dft  \
# dft_id
# lFe254        (-12.69698, 0.001043858)    (-24.260484, 0.001043858)
# lFe259      (-13.306423, 0.0016200055)   (-19.418859, 0.0016200055)
# lFe264     (-12.678945, 0.00087697776)  (-23.198397, 0.00087697776)
# lFe284     (-14.820574, 0.00061130376)  (-33.646124, 0.00061130376)
# lFe274       (-15.53059, 0.0018703372)   (-22.674158, 0.0018703372)
# lFe294      (-15.656377, 0.0012497001)   (-27.408695, 0.0012497001)
# lMgO232     (-11.603985, 0.0038973554)    (-34.78861, 0.0038973554)
# lMgO237     (-9.4796921, 0.0025276343)   (-26.634728, 0.0025276343)
# lMgO262     (-13.418978, 0.0029229211)   (-32.438186, 0.0029229211)
# lMgO242     (-7.1672739, 0.0039618273)   (-29.186139, 0.0039618273)
# lMgO247     (-11.897141, 0.0041335957)   (-36.580349, 0.0041335957)
# lFeMgO353   (-17.430295, 0.0046142433)   (-45.547829, 0.0046142433)
# lFeMgO393   (-13.326945, 0.0067099112)   (-35.078587, 0.0067099112)
# lFeMgO373   (-14.805748, 0.0065424389)   (-42.803225, 0.0065424389)
# lFeMgO358   (-24.413013, 0.0036198563)   (-63.608866, 0.0036198563)
# lFeMgO378    (-15.379767, 0.007033903)    (-40.074604, 0.007033903)
# lFeMgO383    (-24.64771, 0.0042477185)   (-49.775582, 0.0042477185)
# lFe363     /u/smwahl/dat/tdi_20140327-153139.dat         Fe32   4000
# lFe368     /u/smwahl/dat/tdi_20140327-153139.dat         Fe32   5000
# lFe373     /u/smwahl/dat/tdi_20140327-153139.dat         Fe32   6000
# lMgO294    /u/smwahl/dat/tdi_20140327-153139.dat      Mg32O32   4000
# lMgO299    /u/smwahl/dat/tdi_20140327-153139.dat      Mg32O32   5000
# lMgO304    /u/smwahl/dat/tdi_20140327-153139.dat      Mg32O32   6000
# lFeMgO523  /u/smwahl/dat/tdi_20140327-153139.dat  O24Fe24Mg24   4000
#                                              ...          ...    ...
#
#                 volume
# dft_id
# lFe254      393.765521 ...
# lFe259      316.097343 ...
# lFe264      329.808124 ...
# lFe284      364.348531 ...
# lFe274      229.363898 ...
# lFe294      233.875842 ...
# lMgO232     701.366512 ...
# lMgO237     530.864286 ...
# lMgO262     557.415187 ...
# lMgO242     351.073206 ...
# lMgO247     360.347403 ...
# lFeMgO353   842.962639 ...
# lFeMgO393   646.008154 ...
# lFeMgO373   676.499605 ...
# lFeMgO358   743.021676 ...
# lFeMgO378   437.795254 ...
# lFeMgO383   448.015330 ...
# lFe319      303.689075 ...
# lFe329      308.743302 ...
# MgO156      483.183969 ...
# MgO171      491.207740 ...
# MgO161      330.144807 ...
# lFeMgO419   623.670546 ...
# lFeMgO429   635.766912 ...
# lFeSiO145   879.547564 ...
# lFeSiO125   937.306399 ...
# lFeSiO150  1007.641869 ...
# lFeSiO130   787.526310 ...
# lFeSiO135   821.766273 ...
# lFeSiO140   535.754081 ...
# lFeSiO155   548.557633 ...
# lSiO141     806.526317 ...
# lSiO146     866.802876 ...
# lSiO126     933.842443 ...
# lSiO131     723.868955 ...
# lSiO151     760.169637 ...
# lSiO136     485.996149 ...
# lSiO156     498.847219 ...
# lFe289      337.037727 ...
# lFe279      363.462341 ...
# lFe324      220.322164 ...
# lFe269      223.737628 ...
# lMgO257     597.880672 ...
# lMgO227     648.795364 ...
# MgO166      335.027614 ...
# lFeMgO368   731.702715 ...
# lFeMgO388   787.200836 ...
# lFeMgO424   420.279191 ...
# lFeMgO363   427.965540 ...
# lFeMgO454   723.921022 ...
# lFeMgO459   720.300897 ...
# lFeMgO464   724.393111 ...
# lFeMgO449   693.732764 ...
# lFe363      431.003530 ...
# lFe368      468.050403 ...
# lFe373      516.947471 ...
# lMgO294    1069.017558 ...
# lMgO299    1290.229701 ...
# lMgO304    1492.450889 ...
# lFeMgO523  1339.556530 ...
#                    ...
#
# [66 rows x 22 columns]

# %%
# make tdi dataframes that are not in tuple form for easier indexing
def unTuple(df):
    '''Function that takes a dataframe and converts any columns that have the format 
    of a tuple with length 2 into two columns, the first with the original column name
    and the second with a d + the original column name. Columns in this form contain 
    a value and its uncertainty
    '''
    newDf = pd.DataFrame(index=df.index)
    for col in df.columns:
        if isinstance(df[col][0],tuple) and len(df[col][0]) == 2:
            c0 =[ x[0] for x in df[col] ] 
            c1 =[ x[1] for x in df[col] ] 
            newDf[col] = c0
            newDf['d'+col] = c1
        else:
            newDf[col] = df[col]
    
    return newDf

#unTuple(tdi)

# %%
# Split by system (note does not distiguish liquid from solid runs)

# MgO is a phase that may nearly be solid, so we wish to check the shape of the dVcell( lambda) curve
# There may be a problem if this is not nearly linear
mgo_tdi = tdi[tdi.system =='Mg32O32']
fe_tdi = tdi[tdi.system =='Fe32']
femgo_tdi = tdi[tdi.system =='O24Fe24Mg24']
sio2_tdi = tdi[ tdi.system =='Si32O64']
fesio_tdi = tdi[ tdi.system =='Fe24Si24O48']
#mgo_tdi

# break mgo_tdi to solid and liquid
#mgo_tdi_sol = mgo_tdi[mgo_tdi.P_target 
mgo_tdi_liq = mgo_tdi[mgo_tdi.dft_id.apply(lambda x: 'lMgO' in x)]
mgo_tdi_sol = mgo_tdi[mgo_tdi.dft_id.apply(lambda x: not 'lMgO' in x)]

# %%
# Estimate error bars on PV to be ~1% of total P
# Note: this isnt used at the moment and we assume the PV error to not effect results

## change error on PV
#tdi.P_targetV = tdi['P_targetV'].apply(lambda x: (x[0],.01*x[0]) )

# change error on G
#G0 = tdi['G_dft'].tolist()
#PV = tdi['P_targetV'].tolist()
#Gerr = [ (x[0],x[1] + y[1]) for x,y in zip(G0,PV) ]
#tdi.index.tolist()
#tmp_list = []
#for x in Gerr:
#    tmp_list.append([x])
#    
#df = pd.DataFrame(tmp_list)
#df
##df[0].values
##tdi['G_dft'] = df[0].values
##tdi['G_dft']


#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lFe_10000K 2 0 50 50.5  100 101
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lFe_highP 9 12 400 405
'''
You have: angstroms^3 * GPa
You want: eV
	* 0.0062415096
    You want: Hartree
	* 0.00022937127
'''
# rectangular correction is already taken into account, this adds approximate error for not taking into account 'triangular correction'
# .01 assumes the fit pressure was within 1% of the target pressure
Fe_dV = [388.20061372859868 - 387.22523355111809, 328.21811657338174 - 327.39344645830693, 223.47936643323209 - 222.68455089433454 ]
Fe_PdV = 0.00022937127 * np.array(Fe_dV) * .01 * np.array([50.,100.,400.])
Fe_PdV
# must multipy 20 -> 32
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lMgO_10000K 2 0 50 50.5 100 101
# must multipy 20 -> 32
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lMgO_highP 9 12 400 405
MgO_dV = 32./20. * np.array([438.5321581157279 - 437.07322314870572, \
                             348.67417862733947 - 347.51418855162211, 213.82662343284605 - 212.86377223460957] )
MgO_PdV = 0.00022937127 * np.array(MgO_dV) * .01 * np.array([50.,100.,400.])
MgO_PdV
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py ~/dat/pleiades/FeMgO_data/B1MgO_5000K 9 12 100 101 400 405
B1_dV =  np.array([466.87225681639819 - 465.62921679976267, 323.98384254326919 - 322.9072811176448] )
B1_PdV = 0.00022937127 * np.array(B1_dV) * .01 * np.array([100.,400.])
B1_PdV
# no multiplication needed since EOS on correct supercell
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lSiO_10000K 9 12 50 50.5 100 101 400 405
# no multiplication needed since EOS on correct supercell
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lFeSiO_10000K 9 12 50 50.5 100 101 400 405
SiO2_dV = np.array([940.85911504149385 - 937.8945347487105, 758.4327773859128 - 756.04300953513291, 486.46656854587093 - 482.00459614193221] )
FeSiO2_dV = np.array([1007.8226314228897 - 1004.7951276620751, 821.84162373427364 - 819.37280776500268, 537.89857841204116 - 535.88201936442567] )
SiO2_PdV = 0.00022937127 * np.array(SiO2_dV) * .01 * np.array([50.,100.,400.])
FeSiO2_PdV = 0.00022937127 * np.array(FeSiO2_dV) * .01 * np.array([50.,100.,400.])

FeSiO2_PdV
# must multiply 12 -> 24
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lFeMgO_10000K 2 0 50 50.5 100 101
# must multiply 12 -> 24
#! /Users/swahl/code/python/eos_fitting/polytrope_fit.py /Users/swahl/dat/pleiades/FeMgO_data/lFeMgO_highP 9 12 400 405
FeMgO_dV = 24./12. * np.array([423.06732208123009- 421.72686149754594, 340.03279346542007- 338.9554222457329, \
                               214.1679757904188 - 213.26440757825526])
FeMgO_PdV = 0.00022937127 * np.array(FeMgO_dV) * .01 * np.array([50.,100.,400.])
FeMgO_PdV

# estimate error per formula unit
Ps = [50., 100.,400.]
err = Fe_PdV / 32. + FeMgO_PdV / 24. + MgO_PdV / 32.
err_b1 = Fe_PdV[1:] / 32. + FeMgO_PdV[1:] / 24. + B1_PdV / 32.
err_sio = Fe_PdV / 32. + FeSiO2_PdV / 24. + SiO2_PdV / 32.
PVerr = {}
[PVerr.update({x:y}) for x,y in zip(Ps,err) ]
PVerr_b1 = {}
[PVerr_b1.update({x:y}) for x,y in zip(Ps[1:],err_b1) ]
PVerr_sio = {}
[PVerr_sio.update({x:y}) for x,y in zip(Ps,err_sio) ]

# store error estimates in dictionaries referenced by target pressure
print PVerr
print PVerr_b1
print PVerr_sio
# Out:
# {400.0: 0.00013604275774721535, 50.0: 2.4672599061255223e-05, 100.0: 3.9807700407797048e-05}
# {400.0: 0.00012273920999367042, 100.0: 3.5414207667453637e-05}
# {400.0: 0.00022780963411805612, 50.0: 2.8587660107468852e-05, 100.0: 4.663542679963306e-05}

# %%
# Group tdi results by pressure and temperature
a = tdi.groupby(['P_target','temp'])

conds = a.groups
#conds

# %%
keys = conds.keys()
key = keys[4]
cond = tdi.loc[conds[key]]
#cond

# %%
# factors to multiply each system by
#mults_mgo = {'Fe32':-1/32.,'Mg32O32':-1/32.,'O24Fe24Mg24':1/24.}
#mults_sio = {'Fe32':-1/32.,'Si32O64':-1/32.,'Fe24Si24O48':1/24.}

# multiples to reduce to per formula unit (all positive)
mults = { 'Fe32':1/32.,'Mg32O32':1/32.,'O24Fe24Mg24':1/24.,'Si32O64':1/32.,'Fe24Si24O48':1/24.}

keys = conds.keys()

# reactions to identify (perhaps I should have a way of indexing by formula unit)
reactions = [{ 'Fe32':-1.,'Mg32O32':-1.,'O24Fe24Mg24':1.},{ 'Fe32':-1.,'Si32O64':-1.,'Fe24Si24O48':1.} ]

# to categorize reaction based on prefixes list of dft_ids
def catRxn(dft_ids):
    
    # change these to cateforize new reaction types
    rxn_sets = [{'lMgO','lFe','lFeMgO'},{'MgO','lFe','lFeMgO'},{'lSiO','lFeSiO','lFe'}]
    rxn_names = ['MgO_liq','MgO_sol','SiO2_liq']
    
    # remove the final 3 (numeric) characters to obtain the prefixes
    prefixes = set( [ x[:-3] for x in dft_ids ] )
    
    name = None
    for n,r in zip(rxn_names,rxn_sets):
        if set(prefixes) == set(r):
            name = n
            
    return name

#catRxn(['lMgO321','lFe123','lFeMgO444'])

# %%
# sum and store reaction energies
# Note: currently this requires there to be only one entry of a given formula at a given condition

rxn_list = []

for key in keys: # loop over conditions
#for key in [(50.,5000.)]:
    cond = tdi.loc[conds[key]] 
    
    for r in reactions:
        # stores energies for the reaction
        energies_list = []
        dft_ids = []
        mult_list = []
        
        for idx,row in cond.iterrows():
            sys = row['system']
            
            # include only sytems in the reaction
            if sys in r.keys():
                mult = mults[sys] * r[sys]
                mult_list.append(mult)
                arr = np.array(row[['F_dft','P_targetV','U_dft','G_dft','minusTS']].tolist())
                energies = arr * mult
                energies[:,1] = np.abs(energies[:,1]) # all errors positive
                energies_list.append(energies)
                dft_ids.append(row['dft_id'])
    
        #print dft_ids
        #print mult_list
        #print energies_list
        # Sum the energies fro the given reaction
        rxn_energies = np.zeros([5,2])    
        for arr in energies_list:
            rxn_energies += arr

        rxn_energies_eV = rxn_energies*Ha_to_eV
        #dft_ids = cond['dft_id'].tolist()
        
        # categorize reaction
        rxn_type = catRxn(dft_ids)
    
        # check that all systems in reaction are accounted for
        if(len(energies_list) == len(r.keys())): 
           rxn_list.append( [key, rxn_type, key[0], key[1], dft_ids] + [ rxn_energies[i,:] for i in range(5) ] +  \
                [ rxn_energies_eV[i,:] for i in range(5) ] )
        else: 
            #rxn_list.append( [key, key[0], key[1], dft_ids] + [ None for i in range(10) ] )
            pass # don't add incomplete reactions
        
rxn = pd.DataFrame(rxn_list,columns=['cond','rxn_type','P_target','temp','dft_ids','F_dft','P_targetV','U_dft','G_dft','minusTS', \
                             'F_dft_eV','P_targetV_eV','U_dft_eV','G_dft_eV','minusTS_eV'] )
#rxn.set_index('cond',inplace=True,drop=False)

## Skip adding PV errors for now

# add in error estimates on PV to PV and G
#for idx,row in rxn.iterrows():
#    if row['mgo_phase'] == 'l':
#        err = PVerr[row['P_target']]
#        print 'liquid'
#    else:
#        err = PVerr[row['P_target']]
#        print 'b1'

# Does this error cancel out in G? *i'm still not convinced*
# note, to avoid double counting make sure to only do this once after creating the rxn dataframe

#for idx,row in rxn.iterrows():
#    if row['rxn_type']   == 'MgO_liq':
#        err = PVerr[row['P_target']]
#    elif row['rxn_type'] == 'MgO_sol':
#        err = PVerr_b1[row['P_target']]  
#    elif row['rxn_type'] == 'SiO2_liq':
#        err = PVerr_sio[row['P_target']]    
#    else:
#        pass
    
    # to ignore Nones
#    try:
#        row['P_targetV'][1] += err
#        row['G_dft'][1] += err
#        row['P_targetV_eV'][1] += err*Ha_to_eV
#        row['G_dft_eV'][1] += err*Ha_to_eV
#    except:
#        pass

# %%
rxn.sort(['rxn_type','P_target','temp'],inplace=True)
rxn
# Out:
#                 cond  rxn_type  P_target   temp                       dft_ids  \
# 8      (0.0, 4000.0)   MgO_liq         0   4000  [lFe363, lMgO294, lFeMgO523]
# 14     (0.0, 5000.0)   MgO_liq         0   5000  [lFe368, lMgO299, lFeMgO528]
# 4      (0.0, 6000.0)   MgO_liq         0   6000  [lFe373, lMgO304, lFeMgO533]
# 6     [-1.08051161426, 0.0129344777922]   [-3.47167427139, 0.131958517936]
# 18   [-1.77824466017, 0.00939473027582]   [-3.93863522402, 0.185522045355]
# 11   [0.424662840599, 0.00951066210912]  [-3.44385204865, 0.0952767908532]
# 5   [-0.139447854534, 0.00958776103004]   [-4.28731509389, 0.107068074276]
# 15    [0.674408071261, 0.0164226370601]  [-4.29248809134, 0.0983189805685]
# 0    [-0.447513316739, 0.0129968372136]   [-5.72365381806, 0.158877819842]
# 17   [-0.652926667871, 0.0235749792352]   [-2.87422027712, 0.101711031284]
# 3     [-1.80703345393, 0.0243703453091]   [-2.97791379053, 0.124359295103]
# 13     [-2.66984776142, 0.022910851398]   [-2.76363803182, 0.116470457414]
# 20     [-1.8683846368, 0.0256319897834]   [-3.06359676925, 0.140017023004]
# 10    [-2.58097963353, 0.0196786492095]  [-3.02464027184, 0.0982182176871]
# 1     [-2.15109844317, 0.0253865204249]   [-3.86723538731, 0.203219818775]
# 7     [-2.97337260739, 0.0236577471944]   [-3.68642934729, 0.167595182327]
#
# [21 rows x 15 columns]

# %%
# divide rxn dataframe based on the type of reaction
lrxn = rxn[rxn.rxn_type == 'MgO_liq']
srxn = rxn[rxn.rxn_type == 'MgO_sol']
sirxn = rxn[rxn.rxn_type == 'SiO2_liq']
#lrxn

# %%
# Obtain entropies for isentropes in each system:
# adiabats of interest:
# MgO liquid ~< 50 GPa
# MgO Solid > 50 GPa
# FeMgO liquid
trxn = lrxn[(lrxn.P_target == 0) | (lrxn.P_target == 50)]

trxn = trxn.append(srxn)
# collect lambda = 0 runs
dft_list = [ x for x in trxn.dft_ids ]

fe0 = []; mgo0 = []; femgo0 = []
for i in dft_list:
    for j in i:
        if 'FeMgO' in j:
            femgo0.append(j)
        elif 'MgO' in j:
            mgo0.append(j)
        else:
            fe0.append(j)
        
            
#tdi[tdi.dft_id.isin(mgo0)]

# %%
sp.interp?

# %%
# Obtain entropies for isentropes in each system:
# adiabats of interest:
from scipy.interpolate import interp1d

#def linInterp(df,argx,argy,x):
#    # Wrapper sp.interp do do a linear interpolation with extrapolation 
#    #beyond the bounds
#    # df is a dataframe with columns argx and argy
#    # x is the value or array of values to interpolate
#    return sp.interp(x,dft[argx],dft[argy])

def linInterp(xdata,ydata,x):
    '''
    Wrapper sp.interp do do a linear interpolation with extrapolation 
    beyond the bounds
    '''
    return sp.interp(x,xdata,ydata)

# simplify dataframe structure (avoid messy notation with uncertainties in tuples)
fe_tdi2 = unTuple(fe_tdi)
femgo_tdi2 = unTuple(femgo_tdi)
mgo_tdi_liq2 = unTuple(mgo_tdi_liq)
mgo_tdi_sol2 = unTuple(mgo_tdi_sol)

#mgo_tdi_liq2.S_dft

# %%
def estIsentrope(df,s_const):
    '''
    Estimate isentrope for a phase contained in datafram df, at a constant  entropy s_const
    '''
    g = pd.groupby(df,'P_target')
    #g.agg(lambda x: np.polyfit(x['temp'],x['S_dft'][0]))
    
    #s_const = .0016
    Tadiabat = []
    Padiabat = []
    for key, grp in g:
        grp1 = grp.sort('temp')
        t = grp1['temp']
        s = grp1['S_dft']
        
        # extend estimate below lowest temperature
        t0 = 0.
        s0 = s[0] - (s[1] - s[0])/(t[1] - t[0])*t[0]
        textend = np.array([ t0 ] + grp1['temp'].tolist())
        sextend = np.array([ s0] + grp1['S_dft'].tolist())
        
        Tadiabat.append(linInterp(sextend,textend,s_const))
        Padiabat.append(key)
    
    return np.array(Tadiabat), np.array(Padiabat)

Tad,Pad = estIsentrope(femgo_tdi2,.0025)
print Tad,Pad
# Out:
# [  908.23761397  2055.72927464  3138.27792841  4387.17482424] [   0.   50.  100.  400.]

# %%
# Plots

import matplotlib
matplotlib.use('MacOSX')
# %matplotlib 
import matplotlib.pyplot as plt

fig_size = [800/72.27 ,700/72.27]
params = {'backend': 'ps', 'axes.labelsize': 25, 'text.fontsize': 25, 'legend.fontsize': 25,
          'xtick.labelsize': 20, 'ytick.labelsize': 20, 
          'xtick.major.size': 10,'ytick.major.size': 10,
          'xtick.minor.size': 6,'ytick.minor.size': 6,
          'xtick.major.width': 2,'ytick.major.width': 2,
          'xtick.minor.width': 2,'ytick.minor.width': 2,
          'axes.linewidth': 2, 'xaxis.labelpad' : 50,
          'text.usetex': False, 'figure.figsize': fig_size,
          'figure.subplot.bottom': 0.100,'figure.subplot.top': 0.980,'figure.subplot.left': 0.110,'figure.subplot.right': 0.977}
plt.rcParams.update(params)
# Out:
# Using matplotlib backend: MacOSX

# %%
#import matplotlib.pyplot as plt
g = pd.groupby(fe_tdi2,'P_target')
for key, grp in g:
    #print key
    grp1 = grp.sort('temp')
    t = grp1['temp']
    s = grp1['S_dft']
    
    t0 = 0.
    s0 = s[0] - (s[1] - s[0])/(t[1] - t[0])*t[0]
    
    # extend estimate below lowest temperature
    textend = np.array([ t0 ] + grp1['temp'].tolist())
    sextend = np.array([ s0] + grp1['S_dft'].tolist())
    
    #print t
    plt.plot(textend,sextend)
    #grp['D'] = pd.rolling_mean(grp['B'], window=5)    
    #plt.plot(grp['D'], label='rolling ({k})'.format(k=key))
plt.show()

# %%
plt.close('all')
for idx,row in fe_tdi.iterrows():
    
    # get lambda values, dV and std from from the table
    lam = np.array(row['lambdas'])
    dVcell = np.array( [ x[0] for x in row['dVcell'] ] )
    dVsig = np.array( [ x[1] for x in row['dVcell'] ] )
    
    T = row['temp']; Ptar = row['P_target']
    print idx,T, Ptar
    
    # clear figure and plot the new series
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.plot(lam,dVcell, '-b')
    ax.fill_between(lam,dVcell+dVsig,dVcell-dVsig,color='b',alpha=.3)
    ax.set_title('T = {} K, T = {} GPa'.format(T,Ptar))
    ax.set_ylabel('dV / cell (Ha)')
    ax.set_xlabel('lambda')
    

    plt.show()

    
    # wait for a keypress to continue
    #raw_input("Press Enter to continue...")
# Out:
# lFe254 10000.0 50.0
# lFe259
#  8000.0 100.0
# lFe264
#  10000.0 100.0
# lFe284
#  15000.0 100.0
# lFe274
#  12500.0 400.0
# lFe294
#  15000.0 400.0
# lFe319
#  6000.0 100.0
# lFe329
#  7000.0 100.0
# lFe289
#  5000.0 50.0
# lFe279
#  7500.0 50.0
# lFe324
#  8000.0 400.0
# lFe269
#  10000.0 400.0
# lFe363
#  4000.0 0.0
# lFe368
#  5000.0 0.0
# lFe373
#  6000.0 0.0

# %%
# make plot of deltaG vs T trends for each constant P (for MgO reaction)

plt.close('all')

# use latex
plt.rc('text', usetex=False)
#plt.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
plt.rc('font',family='sans-serif')

transition_temps = [] # store inferred transition temperatures
tt_error = [] # store estimated error from a line passing through upper error bars
G_slope = []
G_slope_err = []


fig2 = plt.figure()
ax = fig2.add_subplot(1,1,1)
colors=['b','g','r','c']

minorLocator   = plt.MultipleLocator(0.1)
ax.yaxis.set_minor_locator(minorLocator)
minorLocator   = plt.MultipleLocator(500)
ax.xaxis.set_minor_locator(minorLocator)

ax.axhline(color='k',linewidth=2)


# sort by pressure
lrxn.sort('P_target',inplace=True)

for i,p in enumerate(lrxn['P_target'].unique()):

    # find all conditions
    #a = rxn[rxn['P_target'] == 50 and not rxn['F_dft'] is None ]
    a = lrxn[lrxn['P_target'] == p * pd.notnull(lrxn['F_dft'])]
    
    # sort by temperature
    a.sort('temp',inplace=True)

    # Get delta G data
    deltaG = np.array([ x[0] for x in a['G_dft_eV'].tolist() ])
    deltaG_err = np.array([ x[1] for x in a['G_dft_eV'].tolist() ])
    T = a['temp'].tolist()
    
    #print T, deltaG, deltaG_err
        
    # Guess transition T by linear interpolation
    dGdT = (deltaG[1]-deltaG[0]) / (T[1] - T[0])
    dG = -deltaG[0]
    T_trans = T[0]+dG / dGdT
    dGdT_err = (deltaG[1]+deltaG_err[1]-deltaG[0]-deltaG_err[0]) / (T[1] - T[0])
    dG = -deltaG[0]
    dG_err = -deltaG[0] - deltaG_err[0]
    T_trans = T[0]+dG / dGdT
    tt_upper = T[0]+dG_err / dGdT_err
    print 'predicted transition temperature', T_trans, '+/-',np.abs(T_trans-tt_upper)
    
    transition_temps.append(T_trans)
    tt_error.append(np.abs(T_trans-tt_upper))
    G_slope.append(dGdT)
    G_slope_err.append(np.abs( dGdT - (deltaG[1]-deltaG_err[1]-deltaG[0]+deltaG_err[0]) / (T[1] - T[0]) ) )
    
    print T
    print deltaG
    ax.plot(T,deltaG,'-',color=colors[i],label='{} GPa'.format(p),linewidth=3)    
    (_, caps, _) = ax.errorbar(T,deltaG,deltaG_err,fmt='D',color=colors[i],markersize=10, \
                               linewidth=2,mfc='w',capsize=12)
    ax.plot(T,deltaG,'D',color=colors[i],markersize=10,mec=colors[i],mew=2, mfc='w')

    for cap in caps:
        cap.set_markeredgewidth(2)
    
    # sort by pressure
srxn.sort('P_target',inplace=True)
style=['--r','--c']
colors=['r','c']
for i,p in enumerate(srxn['P_target'].unique()):

    # find all conditions
    #a = rxn[rxn['P_target'] == 50 and not rxn['F_dft'] is None ]
    a = srxn[srxn['P_target'] == p * pd.notnull(srxn['F_dft'])]
    
    # sort by temperature
    a.sort('temp',inplace=True)

    # Get delta G data
    deltaG = np.array([ x[0] for x in a['G_dft_eV'].tolist() ])
    deltaG_err = np.array([ x[1] for x in a['G_dft_eV'].tolist() ])
    #print deltaG, deltaG_err
    T = a['temp'].tolist()
    
    # Guess transition T by linear interpolation
    dGdT = (deltaG[1]-deltaG[0]) / (T[1] - T[0])
    dG = -deltaG[0]
    T_trans = T[0]+dG / dGdT
    dGdT_err = (deltaG[1]+deltaG_err[1]-deltaG[0]-deltaG_err[0]) / (T[1] - T[0])
    dG = -deltaG[0]
    dG_err = -deltaG[0] - deltaG_err[0]
    T_trans = T[0]+dG / dGdT
    tt_upper = T[0]+dG_err / dGdT_err
    print 'predicted transition temperature', T_trans, '+/-',np.abs(T_trans-tt_upper)
    
    transition_temps.append(T_trans)
    tt_error.append(np.abs(T_trans-tt_upper))
    G_slope.append(dGdT)
    G_slope_err.append(np.abs( dGdT - (deltaG[1]-deltaG_err[1]-deltaG[0]+deltaG_err[0]) / (T[1] - T[0]) ) )

    
    ax.plot(T,deltaG,style[i],linewidth=3)
    (_, caps, _) = ax.errorbar(T,deltaG,deltaG_err,fmt='D',color=colors[i],markersize=10, \
                               linewidth=2,mfc='w',capsize=12)
    ax.plot(T,deltaG,'D',color=colors[i],markersize=10,mec=colors[i],mew=2, mfc='w')

    for cap in caps:
        cap.set_markeredgewidth(2)
    
#ax.set_title('G(FeMgO) - G(Fe) - G(MgO)')
#ax.set_ylabel('delta G / formula unit (eV)')
#ax.set_xlabel('T (K)')
ax.set_ylabel(r'$\Delta$G / formula unit (eV)')
ax.set_xlabel(r' T (K)')
ax.legend(loc='upper right',frameon=False,handletextpad=0.1) # ,numpoints=1

# Fix label spacing
ax.xaxis.labelpad = 5
ax.tick_params(axis='x', pad=5)
ax.tick_params(axis='y', pad=5)

ax.set_xlim(3000,16000)
plt.show()
plt.savefig("/Users/swahl/Documents/Presentations/CIPS_2014/images/deltaG.png", transparent = True)
# Out:
# predicted transition temperature 4088.99240522 +/- 21.3751966007
# [4000.0, 5000.0, 6000.0]
# [ 0.03498732 -0.35816219 -0.71506613]
# predicted transition temperature
#  6124.88839543 +/- 33.736024407
# [5000.0, 7500.0, 10000.0]
# [ 0.34255164 -0.41874975 -1.14869654]
# predicted transition temperature
#  6903.26951663 +/- 37.8730588628
# [8000.0, 10000.0]
# [-0.32990883 -0.93153127]
# predicted transition temperature
#  8628.49204792 +/- 65.6525614148
# [12500.0, 15000.0]
# [-1.08051161 -1.77824466]
# predicted transition temperature
#  6752.8005483 +/- 16.9647735229
# predicted transition temperature
#  9202.23765849 +/- 25.5269207979

# %%
lrxn[ lrxn.cond == (50.0,5000.0) ]
# why is P_targetV so far off ?
# Out:
#               cond rxn_type  P_target  temp                       dft_ids  \
# 16  (50.0, 5000.0)  MgO_liq        50  5000  [lFe289, lMgO257, lFeMgO368]
#
#                                      F_dft             P_targetV  \
# 16  [-0.00199273958333, 0.000438233571354]  [0.01458128125, 0.0]
#
#                                   U_dft                                 G_dft  \
# 16  [0.0505472916667, 0.00184482291667]  [0.0125885416667, 0.000438239583333]
#
#                                minusTS                             F_dft_eV  \
# 16  [-0.05254003125, 0.00228305648802]  [-0.0542252017244, 0.0119249419281]
#
#              P_targetV_eV                          U_dft_eV  \
# 16  [0.396776841186, 0.0]  [1.37546175635, 0.0502001845293]
#
#                              G_dft_eV                         minusTS_eV
# 16  [0.342551639462, 0.0119251055224]  [-1.42968695808, 0.0621251264574]
#
# [1 rows x 15 columns]

# %%
#tdi.loc[conds[(50.,5000.)]
#tdi.loc[conds[(50.0, 5000.0)]]

# %%
# add GGA + U test at 50 GPa, 5000K
ggau_rxn = pd.read_pickle('/Users/swahl/dat/pleiades/tables/ggau_test_20140122-132640.df')
ggau_rxn
# Out:
#              cond    rxn_type  P_target  temp                      dft_ids  \
# 0  (50.0, 5000.0)  GGA+U_test        50  5000  [lFe338, FeMgO438, lMgO257]
#
#                                    F_dft                           P_targetV  \
# 0  [-0.0197191041667, 0.000414633850313]  [0.01458128125, 2.46725990613e-05]
#
#                              U_dft                                   G_dft  \
# 0  [0.0209200520833, 0.0030646875]  [-0.00513782291667, 0.000439297599061]
#
#                               minusTS                          F_dft_eV  \
# 0  [-0.04063915625, 0.00347932135031]  [-0.536584112749, 0.01128276086]
#
#                           P_targetV_eV                          U_dft_eV  \
# 0  [0.396776841186, 0.000671375563748]  [0.569263567499, 0.083394387957]
#
#                              G_dft_eV                        minusTS_eV
# 0  [-0.139807271563, 0.0119538955945]  [-1.10584768025, 0.094677148817]
#
# [1 rows x 15 columns]

# %%
print transition_temps
print tt_error
print np.array(G_slope) * 1000
print np.array(G_slope_err) *1000
# Out:
# [4088.9924052239176, 6124.888395433497, 6903.2695166279073, 8628.4920479192697, 6752.800548301484, 9202.2376584928079]
# [21.375196600746676, 33.73602440702507, 37.8730588628232, 65.65256141484133, 16.964773522915493, 25.526920797858111]
# [-0.39314951 -0.30452056 -0.30081122 -0.27909322 -0.5641107  -0.56096069]
# [  2.42578149e-03   1.42564975e-03   2.43201743e-04   1.41589901e-03
#    7.70989209e-05   1.71289992e-03]

# %%
# Compare to melting line from Boates
import pandas as pd
import numpy as np
boates = pd.read_csv('/Users/swahl/dat/boates_mgo.dat')
boates.iloc[:,1]

mossen = pd.read_csv('/Users/swahl/dat/mosenfelder_mgsio3.dat')

boates = boates[boates['P GPa'] > 45.]

# other comparisons: simple core,mantle adiabats,temperature structure of ice giants?,MgSiO3 shock melting points

# simple  core adiabat model (parameters from Labrosse 2003)
alpha = 1.3e-5
Cp = 850

# prem model for outer core
rho_ad_core = np.array([ float(x) for x in '12166.34 12069.24 11946.82 11809.00 11654.78 11483.11 11292.98 11083.35 10853.21 10601.52 10327.26 10029.40 9903.490'.split() ] )[::-1]
P_ad_core = np.array([ float(x) for x in '328.850 318.750 306.150 292.220 277.040 260.680 243.250 224.850 205.600 185.640 165.120 144.190 135.750'.split() ] )[::-1]

To = 7000
T_ad = [To]
T=To
for i in range(1,len(rho_ad_core)):
    dp = (P_ad_core[i] - P_ad_core[i-1] ) *1e9
    dTdP = alpha*T/Cp/rho_ad_core[i-1]
    T += dTdP * dp
    T_ad.append(T)
T_ad.append(T_ad[-1] + (T_ad[-1]-T_ad[-2])/(P_ad_core[-1] - P_ad_core[-2])*(400. - P_ad_core[-1]))
P_ad_core = np.hstack([P_ad_core,400.])
T_ad_6000 = np.array(T_ad)

#T_ad_6000

# %%
# plot isentropes estimated from this data

#print fe_tdi2[['P_target','temp','S_dft']]
#print femgo_tdi2[['P_target','temp','S_dft']]
#print mgo_tdi_liq2[['P_target','temp','S_dft']]

Tad1,Pad1 = estIsentrope(femgo_tdi2,.0031)
Tad2,Pad2 = estIsentrope(femgo_tdi2,.00325)
Tad3,Pad3 = estIsentrope(femgo_tdi2, .0034)

#ax.plot(Pad1,Tad1,'g')
#ax.plot(Pad2,Tad2,'c')
#ax.plot(Pad2,Tad2,'r')

print Pad1,Tad1
print Pad2,Tad2
print Pad3,Tad3

# fit a spline 
from scipy.interpolate import UnivariateSpline
spline = UnivariateSpline(rxn['P_target'].unique(),np.array(transition_temps)[[0,1,4,5]],k=2)
Psolvus = np.linspace(0,500,50)
Tsolvus = spline(Pgrid)
#Tsolvus
# Out:
# [   0.   50.  100.  400.] [ 3044.99621883  5270.39753445  6218.81941915  9495.75503592]
# [   0.   50.  100.  400.] [  3579.18587004   6074.0645994    6988.95479183  10981.13459685]
# [   0.   50.  100.  400.] [  4113.37552126   6877.73166435   8144.97017305  12610.8196466 ]

# %%
# plot solvus closure with simulation T,P

plt.close('all')
# use latex
plt.rc('text', usetex=False)
#plt.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
plt.rc('font',family='sans-serif')

P = rxn['P_target'].unique()
T = np.array(transition_temps)[[0,1,4,5]]
Terr = np.array(tt_error)[[0,1,4,5]]


colors=['b','g','r']

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
minorLocator   = plt.MultipleLocator(500)
ax.yaxis.set_minor_locator(minorLocator)
minorLocator   = plt.MultipleLocator(20)
ax.xaxis.set_minor_locator(minorLocator)

labels = ['{} GPa'.format(p) for p in P] 

ax.axvline(color='k',lw=2)

ax.plot(boates.iloc[:,0],boates.iloc[:,1]*1000.,'--k',lw =4, label='MgO liquidus (Boates)')
#ax.plot(mossen.iloc[:,0],mossen.iloc[:,1],'--g',lw =4, label=r'MgSiO_3 liquidus')

# Plot the conditions with simulations run
ax.plot(lrxn.P_target,lrxn.temp,'s',color='b',markersize=12,mec='b',mew=3, mfc='w',label='liquid MgO')
ax.plot(srxn.P_target,srxn.temp,'D',color='g',markersize=12,mec='g',mew=3, mfc='w',label='solid MgO')

#ax.plot(P,T, '-b',linewidth=4,label='Complete mixing')
#ax.fill_between(P,T+Terr,T-Terr,color='b',alpha=.3)

(_, caps, _) = ax.errorbar(P,T,Terr,fmt='o',color='r',markersize=14, \
                           linewidth=2,mfc='r',capsize=12)
ax.plot(P,T,'o',color='r',markersize=14,mec='r',mew=2, mfc='r',label='solvus closure')

for cap in caps:
    cap.set_markeredgewidth(2)
    
# Plot spline fit
ax.plot(Psolvus,Tsolvus, '-r',linewidth=4)


#ax.plot(P_ad_core,T_ad_6000,'-r',label='Liquid Fe adiabat',lw=4)
#ax.plot(P_ad_core,T_ad_6000+1000,':r',lw=4)

#plt.arrow( 200, 8600, 0, -800, fc="r", ec="r",head_width=5,head_length=50,lw=4, length_includes_head=True )
#plt.arrow( 350, 10270, 0, -800, fc="r", ec="r",head_width=5,head_length=50,lw=4, length_includes_head=True )

plt.show()

#ax.set_title('Predicted transition temperature')
ax.set_ylabel('T (K)')
ax.set_xlabel('P (GPa)')
ax.axhline(color='k')
ax.set_ylim([2000,16000])
ax.set_xlim([-80,480])
ax.legend(loc='lower right',frameon=False,handletextpad=0.1,numpoints=1)

#plt.savefig("/Users/swahl/Documents/Illustrator/AGU_2013_poster/comparison.svg", transparent = True)
plt.savefig("/Users/swahl/Documents/Presentations/CIPS_2014/images/solvus.png", transparent = True)

# %%
# plot solvus closure against adiabats

plt.close('all')
# use latex
plt.rc('text', usetex=False)
#plt.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
plt.rc('font',family='sans-serif')

P = rxn['P_target'].unique()
T = np.array(transition_temps)[[0,1,4,5]]
Terr = np.array(tt_error)[[0,1,4,5]]


colors=['b','g','r']

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
minorLocator   = plt.MultipleLocator(500)
ax.yaxis.set_minor_locator(minorLocator)
minorLocator   = plt.MultipleLocator(20)
ax.xaxis.set_minor_locator(minorLocator)

labels = ['{} GPa'.format(p) for p in P] 

ax.axvline(color='k',lw=2)

ax.plot(boates.iloc[:,0],boates.iloc[:,1]*1000.,'--k',lw =4, label='MgO liquidus (Boates)')
#ax.plot(mossen.iloc[:,0],mossen.iloc[:,1],'--g',lw =4, label=r'MgSiO_3 liquidus')

# Plot the conditions with simulations run
#ax.plot(lrxn.P_target,lrxn.temp,'s',color='b',markersize=12,mec='b',mew=3, mfc='w',label='liquid MgO')
#ax.plot(srxn.P_target,srxn.temp,'D',color='g',markersize=12,mec='g',mew=3, mfc='w',label='solid MgO')

#ax.plot(P,T, '-b',linewidth=4,label='Complete mixing')
#ax.fill_between(P,T+Terr,T-Terr,color='b',alpha=.3)

(_, caps, _) = ax.errorbar(P,T,Terr,fmt='o',color='r',markersize=14, \
                           linewidth=2,mfc='r',capsize=12)
ax.plot(P,T,'o',color='r',markersize=14,mec='r',mew=2, mfc='r',label='solvus closure')

for cap in caps:
    cap.set_markeredgewidth(2)
    
# Plot spline fit
ax.plot(Psolvus,Tsolvus, '-r',linewidth=4)


#ax.plot(P_ad_core,T_ad_6000,'-r',label='Liquid Fe adiabat',lw=4)
#ax.plot(P_ad_core,T_ad_6000+1000,':r',lw=4)

#plt.arrow( 200, 8600, 0, -800, fc="r", ec="r",head_width=5,head_length=50,lw=4, length_includes_head=True )
#plt.arrow( 350, 10270, 0, -800, fc="r", ec="r",head_width=5,head_length=50,lw=4, length_includes_head=True )

dashdot = [8, 4, 2, 4]
line, = ax.plot(Pad1,Tad1,'b-',lw=4,label='FeMgO isentropes')
line.set_dashes(dashdot)
line, = ax.plot(Pad2,Tad2,'b-',lw=4)
line.set_dashes(dashdot)
line, = ax.plot(Pad3,Tad3,'b-',lw=4)
line.set_dashes(dashdot)

#ax.set_title('Predicted transition temperature')
ax.set_ylabel('T (K)')
ax.set_xlabel('P (GPa)')
ax.axhline(color='k')
ax.set_ylim([3000,10000])
ax.set_xlim([-80,480])
ax.legend(loc='lower right',frameon=False,handletextpad=0.1,numpoints=1)

#plt.savefig("/Users/swahl/Documents/Illustrator/AGU_2013_poster/comparison.svg", transparent = True)
plt.savefig("/Users/swahl/Documents/Presentations/CIPS_2014/images/isentropes.png", transparent = True)

# %%
print T
print Terr
# Out:
# [ 4088.99240522  6124.88839543  6752.8005483   9202.23765849]
# [ 21.3751966   33.73602441  16.96477352  25.5269208 ]

# %%
# make plot of deltaG vs T trends for each constant P (for SiO2 reaction)

#plt.close('all')

# use latex
plt.rc('text', usetex=False)
#plt.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
plt.rc('font',family='sans-serif')

transition_temps = [] # store inferred transition temperatures
tt_error = [] # store estimated error from a line passing through upper error bars
G_slope = []
G_slope_err = []


fig2 = plt.figure()
ax = fig2.add_subplot(1,1,1)
colors=['b','g','r']

minorLocator   = plt.MultipleLocator(500)
#ax.yaxis.set_minor_locator(minorLocator)
minorLocator   = plt.MultipleLocator(50)
ax.xaxis.set_minor_locator(minorLocator)

ax.axhline(color='k',linewidth=2)


# sort by pressure
sirxn.sort('P_target',inplace=True)

for i,p in enumerate(sirxn['P_target'].unique()):

    # find all conditions
    #a = rxn[rxn['P_target'] == 50 and not rxn['F_dft'] is None ]
    a = sirxn[sirxn['P_target'] == p * pd.notnull(sirxn['F_dft'])]
    
    # sort by temperature
    a.sort('temp',inplace=True)

    # Get delta G data
    deltaG = np.array([ x[0] for x in a['G_dft_eV'].tolist() ])
    deltaG_err = np.array([ x[1] for x in a['G_dft_eV'].tolist() ])
    T = a['temp'].tolist()
    
    #print T, deltaG, deltaG_err
        
    # Guess transition T by linear interpolation
    dGdT = (deltaG[1]-deltaG[0]) / (T[1] - T[0])
    dG = -deltaG[0]
    T_trans = T[0]+dG / dGdT
    dGdT_err = (deltaG[1]+deltaG_err[1]-deltaG[0]-deltaG_err[0]) / (T[1] - T[0])
    dG = -deltaG[0]
    dG_err = -deltaG[0] - deltaG_err[0]
    T_trans = T[0]+dG / dGdT
    tt_upper = T[0]+dG_err / dGdT_err
    print 'predicted transition temperature', T_trans, '+/-',np.abs(T_trans-tt_upper)
    
    transition_temps.append(T_trans)
    tt_error.append(np.abs(T_trans-tt_upper))
    G_slope.append(dGdT)
    G_slope_err.append(np.abs( dGdT - (deltaG[1]-deltaG_err[1]-deltaG[0]+deltaG_err[0]) / (T[1] - T[0]) ) )
    
    ax.plot(T,deltaG,'-',color=colors[i],label='{} GPa'.format(p),linewidth=3)    
    (_, caps, _) = ax.errorbar(T,deltaG,deltaG_err,fmt='D',color=colors[i],markersize=10, \
                               linewidth=2,mfc='w',capsize=12)
    ax.plot(T,deltaG,'D',color=colors[i],markersize=10,mec=colors[i],mew=2, mfc='w')

    for cap in caps:
        cap.set_markeredgewidth(2)
    
    # sort by pressure
srxn.sort('P_target',inplace=True)
style=['--g','--r']
colors=['g','r']
    
#ax.set_title('G(FeMgO) - G(Fe) - G(MgO)')
#ax.set_ylabel('delta G / formula unit (eV)')
#ax.set_xlabel('T (K)')
ax.set_ylabel(r'$\Delta$G / formula unit (eV)')
ax.set_xlabel(r' T (K)')
ax.legend(loc='upper right',frameon=False,handletextpad=0.1) # ,numpoints=1

# Fix label spacing
ax.xaxis.labelpad = 5
ax.tick_params(axis='x', pad=5)
ax.tick_params(axis='y', pad=5)


#plt.savefig("/Users/swahl/Documents/Illustrator/AGU_2013_poster/deltaG.svg", transparent = True)
# Out:
# predicted transition temperature 3585.64502922 +/- 50.1274132257
# predicted transition temperature
#  2756.11070693 +/- 114.790660808
# predicted transition temperature
#  3459.91113195 +/- 90.7431614911

# %%
# make plots of components versus T for each constant P

plt.close('all')

rxn.sort('P_target',inplace=True)

colors=['b','g','r','c','m']

#for p in rxn['P_target'].unique():
for p in [50.]:

    # find all conditions
    #a = rxn[rxn['P_target'] == 50 and not rxn['F_dft'] is None ]
    a = rxn[rxn['P_target'] == p * pd.notnull(rxn['F_dft'])]
    
    # sort by temperature
    a.sort('temp',inplace=True)
    
    deltaF = np.array([ x[0] for x in a['F_dft_eV'].tolist() ])
    deltaF_err = np.array([ x[1] for x in a['F_dft_eV'].tolist() ])
    deltaPV = np.array([ x[0] for x in a['P_targetV_eV'].tolist() ])
    deltaPV_err = np.array([ x[1] for x in a['P_targetV_eV'].tolist() ])
    deltaU = np.array([ x[0] for x in a['U_dft_eV'].tolist() ])
    deltaU_err = np.array([ x[1] for x in a['U_dft_eV'].tolist() ])
    deltaG = np.array([ x[0] for x in a['G_dft_eV'].tolist() ])
    deltaG_err = np.array([ x[1] for x in a['G_dft_eV'].tolist() ])
    deltaminuTS = np.array([ x[0] for x in a['minusTS_eV'].tolist() ])
    deltaminuTS_err = np.array([ x[1] for x in a['minusTS_eV'].tolist() ]) 
    
    print deltaF, deltaF_err
    print deltaG, deltaG_err
    T = a['temp']
    
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    
    minorLocator   = plt.MultipleLocator(1)
    ax.yaxis.set_minor_locator(minorLocator)
    minorLocator   = plt.MultipleLocator(1000)
    ax.xaxis.set_minor_locator(minorLocator)

    ax.axhline(color='k',linewidth=2)

    
    markers = ['o','o','o','D','D']
    labels = [r'$\Delta$F',r'$\Delta$PV',r'$\Delta$U',r'$\Delta$G',r'-$\Delta$TS']
    for i,x in enumerate(zip([deltaF,deltaPV,deltaU,deltaG,deltaminuTS],
                             [deltaF_err,deltaPV_err,deltaU_err,deltaG_err,deltaminuTS_err])):
        #ax.plot(T,x[0],color=colors[i],label=labels[i])
        #ax.plot(T,x[0],'x',color=colors[i])
        #ax.errorbar(T,x[0],x[1],color=colors[i])
        
        ax.plot(T,x[0],'-',linewidth=3,label=labels[i])
        (_, caps, _) = ax.errorbar(T,x[0],x[1],fmt=markers[i],color=colors[i],markersize=10, \
                               linewidth=2,mfc='w',capsize=12)
        ax.plot(T,x[0],markers[i],color=colors[i],markersize=10,mec=colors[i],mew=2, mfc='w')

        for cap in caps:
            cap.set_markeredgewidth(2)
                         

    #ax.set_title('{} GPa'.format(p))
    ax.set_ylabel('Thermodynamic potential / formula unit (eV)')
    ax.set_xlabel('T (K)')
    ax.set_xlim(4500,10500)
    ax.set_ylim(-4,2)

    
    ax.legend(loc='lower left',frameon=False,handletextpad=0.3) # ,numpoints=1

    # Fix label spacing
    ax.xaxis.labelpad = 5
    ax.tick_params(axis='x', pad=5)
    ax.tick_params(axis='y', pad=5)
    
    plt.savefig("/Users/swahl/Documents/Illustrator/AGU_2013_poster/components.svg", transparent = True)
# Out:
# [-0.0542252  -0.93736613 -0.78293586 -1.99697742 -1.4297411  -2.82505356] [ 0.01192494  0.02357553  0.00836053  0.02437078  0.00943345  0.02291148]
# [ 0.34255164 -0.65292667 -0.41874975 -1.80703345 -1.14869654 -2.66984776] [ 0.01192511  0.02357498  0.00836098  0.02437035  0.009433    0.02291085]

# %%
# make plots of components versus T for each constant T (at 10000 K)

rxn.sort('P_target',inplace=True)

colors=['b','g','r','c','m']

for T in [10000]:

    # find all conditions
    #a = rxn[rxn['P_target'] == 50 and not rxn['F_dft'] is None ]
    a = rxn[rxn['temp'] == T * pd.notnull(rxn['F_dft'])]
    
    # sort by temperature
    a.sort('P_target',inplace=True)
    
    deltaF = np.array([ x[0] for x in a['F_dft_eV'].tolist() ])
    deltaF_err = np.array([ x[1] for x in a['F_dft_eV'].tolist() ])
    deltaPV = np.array([ x[0] for x in a['P_targetV_eV'].tolist() ])
    deltaPV_err = np.array([ x[1] for x in a['P_targetV_eV'].tolist() ])
    deltaU = np.array([ x[0] for x in a['U_dft_eV'].tolist() ])
    deltaU_err = np.array([ x[1] for x in a['U_dft_eV'].tolist() ])
    deltaG = np.array([ x[0] for x in a['G_dft_eV'].tolist() ])
    deltaG_err = np.array([ x[1] for x in a['G_dft_eV'].tolist() ])
    deltaminuTS = np.array([ x[0] for x in a['minusTS_eV'].tolist() ])
    deltaminuTS_err = np.array([ x[1] for x in a['minusTS_eV'].tolist() ]) 
    
    print deltaF, deltaF_err
    print deltaG, deltaG_err
    P = a['P_target']
    
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    labels = ['deltaF','deltaPV','deltaU','deltaG','-deltaTS']
    for i,x in enumerate(zip([deltaF,deltaPV,deltaU,deltaG,deltaminuTS],
                             [deltaF_err,deltaPV_err,deltaU_err,deltaG_err,deltaminuTS_err])):
        ax.plot(P,x[0],color=colors[i],label=labels[i])
        ax.plot(P,x[0],'x',color=colors[i])
        ax.errorbar(P,x[0],x[1],color=colors[i])
                         

    ax.set_title('{} K'.format(T))
    ax.set_ylabel('Thermodynamic potential / formula unit (eV)')
    ax.set_xlabel('P (GPa)')
    ax.axhline(color='k')

    ax.legend(loc='upper left')
# Out:
# [-1.4297411  -2.82505356 -2.69236518 -1.21973639 -1.37246369 -2.51038282] [ 0.00943345  0.02291148  0.01967823  0.01064913  0.01299731  0.02538606]
# [-1.14869654 -2.66984776 -2.58097963 -0.93153127 -0.44751332 -2.15109844] [ 0.009433    0.02291085  0.01967865  0.01064872  0.01299684  0.02538652]

# %%
# predict new volumes based on coeff. of thermal expansion

# Group tdi results by 
P_sys = tdi.groupby(['P_target','system'])

grps = P_sys.groups   

def newV(T,To,Vo,alpha):
    V = Vo + Vo * ( T - To) * alpha
    a = V**(1/3.)
    return V,a
alpha_data = {}

# store alpha and relavent data for finding new volumes
for key in grps.keys():
    runs = grps[key]
    T1 = tdi.loc[runs[0]]['temp'] 
    T2 = tdi.loc[runs[1]]['temp']
    V1 = tdi.loc[runs[0]]['volume']
    V2 = tdi.loc[runs[1]]['volume']
    alpha = ( V2 - V1 ) / float(V1) / float( T2 - T1 )
    alpha_data.update({key:[T1,V1,alpha]})
    
    print 'Alpha for {} : {}'.format(key,alpha)
    print '    V1 = {} , T1 = {}'.format(V1,T1)
# Out:
# Alpha for (50.0, 'Mg32O32') : 3.40634469632e-05
#     V1 = 597.880672297 , T1 = 5000.0
# Alpha for (400.0, 'Mg32O32') : 1.05666813318e-05
#     V1 = 351.073206244 , T1 = 12500.0
# Alpha for (50.0, 'Fe32') : 3.13610164952e-05
#     V1 = 337.037726696 , T1 = 5000.0
# Alpha for (400.0, 'O24Fe24Mg24') : 9.18738851955e-06
#     V1 = 427.965540106 , T1 = 10000.0
# Alpha for (400.0, 'Fe32') : 1.0058691577e-05
#     V1 = 223.737628462 , T1 = 10000.0
# Alpha for (100.0, 'Fe32') : 2.16875929295e-05
#     V1 = 316.097342819 , T1 = 8000.0
# Alpha for (100.0, 'O24Fe24Mg24') : 2.35998964391e-05
#     V1 = 646.008154153 , T1 = 8000.0
# Alpha for (100.0, 'Mg32O32') : 2.50072392005e-05
#     V1 = 530.864286182 , T1 = 8000.0
# Alpha for (50.0, 'O24Fe24Mg24') : 3.03391635305e-05
#     V1 = 731.702715426 , T1 = 5000.0

# %%
# find new volumes at new temperatures based on existing runs
for x,t in zip([(100.0, 'Fe32'),(100.0, 'O24Fe24Mg24'),(400.0, 'Fe32'),(400.0, 'O24Fe24Mg24')],
               [7000.,7000.,8000.,8000.]):
    a = alpha_data[x]
    print x, newV(t,a[0],a[1],a[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-79d2217d4b29> in <module>()
#       2 for x,t in zip([(100.0, 'Fe32'),(100.0, 'O24Fe24Mg24'),(400.0, 'Fe32'),(400.0, 'O24Fe24Mg24')],
#       3                [7000.,7000.,8000.,8000.]):
# ----> 4     a = alpha_data[x]
#       5     print x, newV(t,a[0],a[1],a[2])
#
# NameError: name 'alpha_data' is not defined

# %%
# find new volumes at new temperatures based on volumes from a fit EOS

#Volumes:  [466.87225681639819, 323.98384254326919] fit Eos at 5000.
to = 5000.

for x,t,v in zip([(100.0, 'Mg32O32'),(100.0, 'Mg32O32'),(400.0, 'Mg32O32'),(400.0, 'Mg32O32')],
               [6000.,8000.,8000.,10000.],
               [466.87225681639819,466.87225681639819,323.98384254326919,323.98384254326919]):
    a = alpha_data[x]
    print x, newV(t,to,v,a[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-e761f4308cd5> in <module>()
#       7                [6000.,8000.,8000.,10000.],
#       8                [466.87225681639819,466.87225681639819,323.98384254326919,323.98384254326919]):
# ----> 9     a = alpha_data[x]
#      10     print x, newV(t,to,v,a[2])
#
# NameError: name 'alpha_data' is not defined

# %%
dft
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 0 to 49
# Data columns (total 8 columns):
# dir         175  non-null values
# hostname    175  non-null values
# id          175  non-null values
# k_spring    50  non-null values
# lambda      175  non-null values
# system      175  non-null values
# temp        175  non-null values
# volume      175  non-null values
# dtypes: float64(3), object(5)

# %%
dft['volume']
# Out:
# 0     393.765521
# 1     393.765521
# 2     393.765521
# 3     393.765521
# 4     393.765521
# 5     316.097343
# 6     316.097343
# 7     316.097343
# 8     316.097343
# 9     316.097343
# 10    329.808124
# 11    329.808124
# 12    329.808124
# 13    329.808124
# 14    329.808124
# ...
# 35    623.670546
# 36    623.670546
# 37    623.670546
# 38    623.670546
# 39    623.670546
# 40    420.279191
# 41    420.279191
# 42    420.279191
# 43    420.279191
# 44    420.279191
# 45    635.766912
# 46    635.766912
# 47    635.766912
# 48    635.766912
# 49    635.766912
# Name: volume, Length: 175, dtype: float64
